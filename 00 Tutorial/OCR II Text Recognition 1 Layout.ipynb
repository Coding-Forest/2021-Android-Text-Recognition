# %% [markdown]
# # Development Learning Journal 1. Initial Settings & `activity_main.xml`

# %% [markdown]
# ### **Notes and References**
#
# Hi. I'm currently learning android development and this is my personal learning notebook.
#
# All the code is from GeeksforGeeks and you can watch the original tutorial in the below link. Have fun learning :) !
#
# https://www.youtube.com/watch?v=wFHR-dR7TpQ&ab_channel=GeeksforGeeks

# %% [markdown]
# # New Concepts & Methods
# - `android:layout_centerHorizontal="true"`
# - `android:layout_marginStart="20dp"`
# - `android:layout_marginEnd="20dp"`
# - `android:textAllCaps="false"`
# - `android:background="@drawable/button_back"`
# - `app:backgroundTint="@color/yellow"`:
#   - Attention! this is `app`, NOT `android`!

# %% [markdown]
# # Dependencies & External resources configration

# %% [markdown]
# ## 1 Firebase
#
# https://console.firebase.google.com

# %%
path1 = "/content/here/MyDrive/Android/Text Recognition App/01 Tool-Firebase.png"
path2 = "/content/here/MyDrive/Android/Text Recognition App/02 Firebase-ML Kit.png"
path3 = "/content/here/MyDrive/Android/Text Recognition App/03 Add ML Kit to your app.png"

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 25))

img1 = cv2.imread(path1)
img2 = cv2.imread(path2)
img3 = cv2.imread(path3)

ax[0].imshow(img1)
ax[0].axis('off')
ax[1].imshow(img2)
ax[1].axis('off')
ax[2].imshow(img3)
ax[2].axis('off')
plt.tight_layout()

# %% [markdown]
# ## 2 `Dependencies` - Firebase & ML Kit
#
# Add in `build.gradle (Module)`:
#
# 1. Firebase
# 2. ML Kit Text Recognition
#
# - Remove:
#   - `implementation 'com.google.firebase:firebase-ml-vision:24.0.1'`
# - Add instead:
#    - `implementation 'com.google.android.gms:play-services-mlkit-text-recognition:16.2.0'`

# %%
dependencies {

    implementation 'androidx.appcompat:appcompat:1.3.1'
    implementation 'com.google.android.material:material:1.4.0'
    implementation 'androidx.constraintlayout:constraintlayout:2.1.0'
    implementation 'com.google.firebase:firebase-core:19.0.0'                           # Add this
    implementation 'com.google.android.gms:play-services-mlkit-text-recognition:16.2.0' # Add this
    testImplementation 'junit:junit:4.+'
    androidTestImplementation 'androidx.test.ext:junit:1.1.3'
    androidTestImplementation 'androidx.test.espresso:espresso-core:3.4.0'
}

# Then sync now!

# %% [markdown]
# ## 3 Set `colors.xml`
#
# - path: `[res]`-`[values]`-`[colors.xml]`

# %%
<?xml version="1.0" encoding="utf-8"?>
<resources>
    <color name="purple_200">#FFBB86FC</color>
    <color name="purple_500">#FF6200EE</color>
    <color name="purple_700">#FF3700B3</color>
    <color name="teal_200">#FF03DAC5</color>
    <color name="teal_700">#FF018786</color>
    <color name="black">#FF000000</color>
    <color name="white">#FFFFFFFF</color>

    <color name="black_shade_1">#292D36</color> # add this
    <color name="yellow">#ffa500</color>        # add this. (yellow for text)
</resources>

# %% [markdown]
# ## 4 Set permissions in `AndroidManifest.xml`
# - for camera and
# - for internet

# %%
<?xml version="1.0" encoding="utf-8"?>
<manifest xmlns:android="http://schemas.android.com/apk/res/android"
    package="com.example.textdetector">

    <uses-permission android:name="android.permission.CAMERA"/>     # add this
    <uses-permission android:name="android.permission.INTERNET"/>   # add this.

    <application
        ...
        
    </application>
</manifest>

# %% [markdown]
# ## 5 Image resources into `[res] > [drawable]`

# %%
fig, ax = plt.subplots(1, 2, figsize=(13, 25))

path1 = "/content/here/MyDrive/Android/Text Recognition App/Drawable 01.png"
path2 = "/content/here/MyDrive/Android/Text Recognition App/Drawable 02.png"

img1 = cv2.imread(path1)
img2 = cv2.imread(path2)

ax[0].imshow(img1)
ax[0].axis('off')
ax[1].imshow(img2)
ax[1].axis('off')
plt.tight_layout()

# %% [markdown]
# ## 6 Set App Icon
# in `AndroidManifest.xml`

# %%
path1 = "/content/here/MyDrive/Android/Text Recognition App/App Icon 01.png"
path2 = "/content/here/MyDrive/Android/Text Recognition App/App Icon 02.png"

fig, ax = plt.subplots(1, 2, figsize=(13, 25))

img1 = cv2.imread(path1)
img2 = cv2.imread(path2)

ax[0].imshow(img1)
ax[0].axis('off')
ax[1].imshow(img2)
ax[1].axis('off')
plt.tight_layout()

# %%
<?xml version="1.0" encoding="utf-8"?>
<manifest xmlns:android="http://schemas.android.com/apk/res/android"
    package="com.example.textdetector">

    <uses-permission android:name="android.permission.CAMERA"/>
    <uses-permission android:name="android.permission.INTERNET"/>

    <application
        android:allowBackup="true"
        android:icon="@drawable/scanner"      # Change this to icon of your choice.
        android:label="@string/app_name"
        android:roundIcon="@drawable/scanner" # Change this as well.
        ...
    </application>

</manifest>

# %% [markdown]
# ## 7 `Drawable Resource File`
# - for a custom made button

# %%
path1 = "/content/here/MyDrive/Android/Text Recognition App/Drawable resource file 01.png"
path2 = "/content/here/MyDrive/Android/Text Recognition App/Drawable resource file 02.png"
path3 = "/content/here/MyDrive/Android/Text Recognition App/Drawable resource file 03.png"

paths = [path1, path2, path3]

for path in paths:
    show(path)
    print('')
# Out:
# <PIL.Image.Image image mode=RGB size=732x185 at 0x7FB28FAACBD0>
# <PIL.Image.Image image mode=RGB size=825x484 at 0x7FB28FAAC390>
# <PIL.Image.Image image mode=RGB size=862x803 at 0x7FB28FAAC750>

# %% [markdown]
# ## 8 Create components - `ImageView`, `TextView` & `Button`

# %%
path1 = "/content/here/MyDrive/Android/Text Recognition App/Layout - TextView.png"
path2 = "/content/here/MyDrive/Android/Text Recognition App/Layout - Button.png"

paths = [path1, path2]

for path in paths:
    show(path)
    print('')
# Out:
# <PIL.Image.Image image mode=RGB size=845x505 at 0x7FB28FA98F10>
# <PIL.Image.Image image mode=RGB size=666x474 at 0x7FB29A0CB1D0>

# %%
# activity_main.xml

<?xml version="1.0" encoding="utf-8"?>
<RelativeLayout xmlns:android="http://schemas.android.com/apk/res/android"
    xmlns:app="http://schemas.android.com/apk/res-auto"
    xmlns:tools="http://schemas.android.com/tools"
    android:layout_width="match_parent"
    android:layout_height="match_parent"
    android:background="@color/black_shade_1"
    tools:context=".MainActivity">

    <ImageView
        android:id="@+id/idVILogo"
        android:layout_width="200dp"
        android:layout_height="200dp"
        android:layout_centerHorizontal="true"
        android:src="@drawable/scanner"
        android:layout_marginTop="70dp"
        />

    <TextView
        android:id="@+id/idTVHead"
        android:layout_width="match_parent"
        android:layout_height="wrap_content"
        android:layout_below="@id/idVILogo"
        android:text="Welcome to Text Detector"
        android:textAlignment="center"
        android:gravity="center"
        android:layout_centerHorizontal="true"
        android:textColor="@color/yellow"
        android:textSize="18sp"
        android:textStyle="bold"
        android:layout_marginStart="20dp"
        android:layout_marginEnd="20dp"
        android:layout_marginTop="30dp"
        android:layout_marginBottom="10dp"/>

    <Button
        android:id="@+id/idBtnCapture"
        android:layout_width="match_parent"
        android:layout_height="wrap_content"
        android:layout_below="@id/idTVHead"
        android:layout_marginStart="20dp"
        android:layout_marginEnd="20dp"
        android:layout_marginTop="30dp"
        android:text="Capture Image"
        android:textAllCaps="false"
        android:background="@drawable/button_back"
        app:backgroundTint="@color/yellow"
        />

</RelativeLayout>
