# %% [markdown]
# # Development Learning Journal 3. Texting & Debugging

# %% [markdown]
# ### **Notes and References**
#
# Hi. I'm currently learning android development and this is my personal learning notebook.
#
# All the code is from GeeksforGeeks and you can watch the original tutorial in the below link. Have fun learning :) !
#
# https://www.youtube.com/watch?v=wFHR-dR7TpQ&ab_channel=GeeksforGeeks

# %% [markdown]
# # 1 Testing

# %% [markdown]
# ## i. Connect to real phone

# %% [markdown]
# ## ii. Testing Result
# - Sucessful:
#   - `private boolean checkPermissions()`
#   - `private void requestPermissions()`
#   - `public void onRequestPermissionsResult`

# %%
path = "/content/here/MyDrive/Android/Text Recognition App/onRequestPermissionsResult.png"
show(path)
# Out:
# <PIL.Image.Image image mode=RGB size=1554x577 at 0x7F1C068E6490>

# %%
# Test result. 'Detect Text' not working properly.

# %% [markdown]
# # 2 Error Log
# - No `LogCat` message. But the app does not detect text.
#   - When click `MainActivity.[Capture Image]` - `ScannerActivity.[Take a Photo]` it works fine.
#     - Then it does not show the detected image. Nor clicking `ScannerActivity.[Detect text]` doesn't work.
#     - Clicking the button brings me back to `MainActivity.[Capture Image]`.

# %%
# Activity cycle. 
# Application does not fail but doesn't detect texts either.
